# %%
# Import required libraries
import pandas as pd
import numpy as np
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import silhouette_score
import holoviews as hv
from holoviews import dim, opts
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="be8e62e5-d6ec-4a6b-aa48-a6db266a4ab9" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6e9d9288-1ef5-4f20-baf2-d923d0e4dff4":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"0ce123e5035c4a0c9c03e02c2e9a50a8","client_comm_id":"bad76968d5e7431ead2eebeef02ff931"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"6e9d9288-1ef5-4f20-baf2-d923d0e4dff4","roots":{"p1002":"be8e62e5-d6ec-4a6b-aa48-a6db266a4ab9"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## Uploading Dataframe

# %%
# Load the data
df_spotify = pd.read_csv("../Spotify/Resources/Spotify_data.csv")

# Shift index from 0-based to 1-based
df_spotify.index = df_spotify.index + 1
df_spotify.index.name = "spotify_user"
df_spotify.head(50)
# Out:
#                 Age  Gender spotify_usage_period  \
# spotify_user
# 1             20-35  Female    More than 2 years
# 2             12-20    Male    More than 2 years
# 3             35-60  Others   6 months to 1 year
# 4             20-35  Female    1 year to 2 years
# 5             20-35  Female    1 year to 2 years
# 6             20-35    Male    More than 2 years
# 7             20-35  Female    1 year to 2 years
# 8             20-35  Female   Less than 6 months
# 9             20-35  Female   Less than 6 months
# 10            20-35  Female    More than 2 years
# 11            20-35  Female    More than 2 years
# 12            20-35  Female    1 year to 2 years
# 13            20-35  Female    1 year to 2 years
# 14            20-35  Female    More than 2 years
# 15            20-35  Female    More than 2 years
# 16            20-35  Female    More than 2 years
# 17            20-35  Female   Less than 6 months
# 18            20-35  Female   Less than 6 months
# 19            20-35  Female    More than 2 years
# 20            20-35  Female    1 year to 2 years
# 21            20-35  Female    1 year to 2 years
# 22            20-35    Male    More than 2 years
# 23            20-35  Female   Less than 6 months
# 24            20-35  Female    More than 2 years
# 25            20-35    Male    More than 2 years
# 26            20-35  Female    1 year to 2 years
# 27            12-20    Male   6 months to 1 year
# 28            35-60    Male   Less than 6 months
# 29            20-35  Female   Less than 6 months
# 30            20-35  Female   6 months to 1 year
# 31            20-35  Female   6 months to 1 year
# 32            20-35    Male    1 year to 2 years
# 33            12-20    Male    More than 2 years
# 34            12-20    Male    More than 2 years
# 35            20-35  Female   Less than 6 months
# 36            12-20    Male    1 year to 2 years
# 37            20-35  Female    More than 2 years
# 38            20-35  Female    More than 2 years
# 39            12-20  Female    More than 2 years
# 40            12-20  Female    More than 2 years
# 41            12-20  Female    More than 2 years
# 42            12-20    Male    1 year to 2 years
# 43            12-20  Female    More than 2 years
# 44            12-20    Male    1 year to 2 years
# 45            20-35  Female   Less than 6 months
# 46            20-35    Male    1 year to 2 years
# 47            12-20    Male    1 year to 2 years
# 48            35-60    Male    1 year to 2 years
# 49            20-35  Female   Less than 6 months
# 50            20-35    Male    1 year to 2 years
#
#                                        spotify_listening_device  \
# spotify_user
# 1                            Smart speakers or voice assistants
# 2                                            Computer or laptop
# 3                            Smart speakers or voice assistants
# 4                Smartphone, Smart speakers or voice assistants
# 5                                                    Smartphone
# 6                                                    Smartphone
# 7                                                    Smartphone
# 8                                                    Smartphone
# 9                                                    Smartphone
# 10                                                   Smartphone
# 11                                                   Smartphone
# 12                                                   Smartphone
# 13                               Smartphone, Computer or laptop
# 14                                                   Smartphone
# 15                                                   Smartphone
# 16                                                   Smartphone
# 17                                                   Smartphone
# 18                                                   Smartphone
# 19                                                   Smartphone
# 20                                                   Smartphone
# 21                                                   Smartphone
# 22                                                   Smartphone
# 23                                                   Smartphone
# 24            Smartphone, Computer or laptop, Smart speakers...
# 25                               Smartphone, Computer or laptop
# 26                                                   Smartphone
# 27               Smartphone, Smart speakers or voice assistants
# 28                                                   Smartphone
# 29                                                   Smartphone
# 30                               Smartphone, Computer or laptop
# 31                                                   Smartphone
# 32                                                   Smartphone
# 33                                                   Smartphone
# 34                                                   Smartphone
# 35                                                   Smartphone
# 36                                                   Smartphone
# 37                               Smartphone, Computer or laptop
# 38                               Smartphone, Computer or laptop
# 39                                                   Smartphone
# 40                               Smartphone, Computer or laptop
# 41                                                   Smartphone
# 42                                                   Smartphone
# 43                                                   Smartphone
# 44                               Smartphone, Computer or laptop
# 45                                                   Smartphone
# 46                                                   Smartphone
# 47                                                   Smartphone
# 48               Smartphone, Smart speakers or voice assistants
# 49                                 Smartphone, Wearable devices
# 50            Smartphone, Computer or laptop, Smart speakers...
#
#                 spotify_subscription_plan premium_sub_willingness  \
# spotify_user
# 1                     Free (ad-supported)                     Yes
# 2                     Free (ad-supported)                     Yes
# 3                     Free (ad-supported)                     Yes
# 4                     Free (ad-supported)                      No
# 5                     Free (ad-supported)                      No
# 6                     Free (ad-supported)                      No
# 7                     Free (ad-supported)                      No
# 8                     Free (ad-supported)                      No
# 9                     Free (ad-supported)                     Yes
# 10                    Free (ad-supported)                      No
# 11                    Free (ad-supported)                      No
# 12                    Free (ad-supported)                      No
# 13                    Free (ad-supported)                      No
# 14                    Free (ad-supported)                      No
# 15                    Free (ad-supported)                     Yes
# 16                    Free (ad-supported)                      No
# 17                    Free (ad-supported)                     Yes
# 18                    Free (ad-supported)                      No
# 19                    Free (ad-supported)                      No
# 20                    Free (ad-supported)                     Yes
# 21                    Free (ad-supported)                      No
# 22                    Free (ad-supported)                     Yes
# 23                    Free (ad-supported)                      No
# 24            Premium (paid subscription)                     Yes
# 25            Premium (paid subscription)                     Yes
# 26                    Free (ad-supported)                      No
# 27            Premium (paid subscription)                     Yes
# 28                    Free (ad-supported)                      No
# 29                    Free (ad-supported)                      No
# 30                    Free (ad-supported)                      No
# 31                    Free (ad-supported)                      No
# 32                    Free (ad-supported)                      No
# 33                    Free (ad-supported)                      No
# 34                    Free (ad-supported)                     Yes
# 35                    Free (ad-supported)                      No
# 36                    Free (ad-supported)                      No
# 37                    Free (ad-supported)                      No
# 38                    Free (ad-supported)                     Yes
# 39                    Free (ad-supported)                      No
# 40                    Free (ad-supported)                      No
# 41                    Free (ad-supported)                      No
# 42                    Free (ad-supported)                      No
# 43                    Free (ad-supported)                     Yes
# 44                    Free (ad-supported)                      No
# 45                    Free (ad-supported)                      No
# 46                    Free (ad-supported)                      No
# 47                    Free (ad-supported)                      No
# 48                    Free (ad-supported)                     Yes
# 49                    Free (ad-supported)                      No
# 50            Premium (paid subscription)                     Yes
#
#                       preffered_premium_plan preferred_listening_content  \
# spotify_user
# 1                   Family Plan-Rs 179/month                     Podcast
# 2             Individual Plan- Rs 119/ month                     Podcast
# 3                   Student Plan-Rs 59/month                     Podcast
# 4                                        NaN                       Music
# 5                                        NaN                       Music
# 6                                        NaN                       Music
# 7                                        NaN                       Music
# 8                                        NaN                       Music
# 9             Individual Plan- Rs 119/ month                       Music
# 10                                       NaN                       Music
# 11                                       NaN                       Music
# 12                                       NaN                       Music
# 13                                       NaN                       Music
# 14                                       NaN                       Music
# 15                                       NaN                       Music
# 16                                       NaN                       Music
# 17            Individual Plan- Rs 119/ month                       Music
# 18                                       NaN                       Music
# 19                                       NaN                       Music
# 20            Individual Plan- Rs 119/ month                       Music
# 21                                       NaN                       Music
# 22            Individual Plan- Rs 119/ month                       Music
# 23                                       NaN                       Music
# 24            Individual Plan- Rs 119/ month                       Music
# 25                  Family Plan-Rs 179/month                       Music
# 26                                       NaN                       Music
# 27                  Student Plan-Rs 59/month                     Podcast
# 28                                       NaN                       Music
# 29                                       NaN                       Music
# 30                                       NaN                     Podcast
# 31                                       NaN                       Music
# 32                                       NaN                       Music
# 33                                       NaN                       Music
# 34                                       NaN                       Music
# 35                                       NaN                       Music
# 36                                       NaN                       Music
# 37                                       NaN                       Music
# 38            Individual Plan- Rs 119/ month                       Music
# 39                                       NaN                       Music
# 40                                       NaN                       Music
# 41                                       NaN                       Music
# 42                                       NaN                       Music
# 43                  Student Plan-Rs 59/month                       Music
# 44                                       NaN                       Music
# 45                                       NaN                       Music
# 46                                       NaN                       Music
# 47                                       NaN                     Podcast
# 48                  Student Plan-Rs 59/month                     Podcast
# 49                                       NaN                       Music
# 50            Individual Plan- Rs 119/ month                       Music
#
#                         fav_music_genre music_time_slot  \
# spotify_user
# 1                                Melody           Night
# 2                                   Rap       Afternoon
# 3                                   Pop           Night
# 4                                Melody           Night
# 5                                Melody           Night
# 6                                   Pop           Night
# 7                                Melody         Morning
# 8                                Melody           Night
# 9                                Melody       Afternoon
# 10                               Melody           Night
# 11                               Melody       Afternoon
# 12                               Melody           Night
# 13                               Melody         Morning
# 14                               Melody           Night
# 15                                  Pop         Morning
# 16                                  Pop       Afternoon
# 17                               Melody       Afternoon
# 18                               Melody           Night
# 19                               Melody           Night
# 20                               Melody           Night
# 21                               Melody           Night
# 22            Classical & melody, dance         Morning
# 23                               Melody           Night
# 24                            classical           Night
# 25                                 Rock           Night
# 26                                  Pop           Night
# 27                                  Rap         Morning
# 28                            Old songs           Night
# 29                                  Pop           Night
# 30                               Melody           Night
# 31                               Melody         Morning
# 32                                  Pop           Night
# 33                                  Pop           Night
# 34                                  Pop           Night
# 35                               Melody           Night
# 36                                  Rap           Night
# 37                                  Pop         Morning
# 38                               Melody           Night
# 39                               Melody           Night
# 40                                  Pop           Night
# 41                               Melody           Night
# 42                                  Pop           Night
# 43                                  Pop           Night
# 44                            classical       Afternoon
# 45                               Melody           Night
# 46                               Melody           Night
# 47                            classical       Afternoon
# 48                               Melody         Morning
# 49                               Melody         Morning
# 50                     Electronic/Dance           Night
#
#                                          music_Influencial_mood  \
# spotify_user
# 1                                         Sadness or melancholy
# 2                                  Social gatherings or parties
# 3                                  Relaxation and stress relief
# 4             Relaxation and stress relief, Social gathering...
# 5                                  Relaxation and stress relief
# 6                                    Uplifting and motivational
# 7                                  Relaxation and stress relief
# 8                                  Social gatherings or parties
# 9             Relaxation and stress relief, Uplifting and mo...
# 10                                 Relaxation and stress relief
# 11            Relaxation and stress relief, Uplifting and mo...
# 12            Relaxation and stress relief, Uplifting and mo...
# 13                                 Relaxation and stress relief
# 14            Relaxation and stress relief, Uplifting and mo...
# 15                                 Relaxation and stress relief
# 16            Relaxation and stress relief, Uplifting and mo...
# 17                                 Relaxation and stress relief
# 18                                 Social gatherings or parties
# 19                                 Relaxation and stress relief
# 20                                        Sadness or melancholy
# 21            Relaxation and stress relief, Sadness or melan...
# 22                                 Relaxation and stress relief
# 23                                 Relaxation and stress relief
# 24            Relaxation and stress relief, Uplifting and mo...
# 25            Relaxation and stress relief, Sadness or melan...
# 26                                 Relaxation and stress relief
# 27                                 Relaxation and stress relief
# 28                                 Relaxation and stress relief
# 29                                 Relaxation and stress relief
# 30            Relaxation and stress relief, Uplifting and mo...
# 31                                 Relaxation and stress relief
# 32                                 Relaxation and stress relief
# 33                                   Uplifting and motivational
# 34                                 Relaxation and stress relief
# 35            Relaxation and stress relief, Uplifting and mo...
# 36                                   Uplifting and motivational
# 37                                   Uplifting and motivational
# 38            Relaxation and stress relief, Social gathering...
# 39                                 Relaxation and stress relief
# 40            Relaxation and stress relief, Uplifting and mo...
# 41                                 Relaxation and stress relief
# 42                                 Relaxation and stress relief
# 43                                   Uplifting and motivational
# 44            Relaxation and stress relief, Uplifting and mo...
# 45            Relaxation and stress relief, Sadness or melan...
# 46                                 Relaxation and stress relief
# 47                                        Sadness or melancholy
# 48                                        Sadness or melancholy
# 49                                 Relaxation and stress relief
# 50            Relaxation and stress relief, Uplifting and mo...
#
#                                          music_lis_frequency  \
# spotify_user
# 1                                               leisure time
# 2                                            Workout session
# 3                               Study Hours, While Traveling
# 4                Office hours, Workout session, leisure time
# 5                                               leisure time
# 6                                            Workout session
# 7                                               Office hours
# 8                                               leisure time
# 9                              While Traveling, leisure time
# 10            Office hours, While Traveling, Workout session
# 11                             While Traveling, leisure time
# 12                             While Traveling, leisure time
# 13                                              Office hours
# 14                             Office hours, While Traveling
# 15                                              Office hours
# 16               Office hours, While Traveling, leisure time
# 17                             While Traveling, leisure time
# 18                                        Social gatherings
# 19                                              leisure time
# 20                             While Traveling, leisure time
# 21                             While Traveling, leisure time
# 22                                              Office hours
# 23                                           While Traveling
# 24            While Traveling, Workout session, leisure time
# 25                                               Study Hours
# 26            While Traveling, Workout session, leisure time
# 27            Office hours, While Traveling, Workout session
# 28                                              leisure time
# 29                             Office hours, While Traveling
# 30                                 Study Hours, leisure time
# 31                                           While Traveling
# 32                                              Office hours
# 33                                           Workout session
# 34                                           While Traveling
# 35                             While Traveling, leisure time
# 36                                           Workout session
# 37               Office hours, While Traveling, leisure time
# 38            While Traveling, Workout session, leisure time
# 39                             While Traveling, leisure time
# 40                                 Study Hours, leisure time
# 41                             While Traveling, leisure time
# 42                          While Traveling, Workout session
# 43                Study Hours, Workout session, leisure time
# 44            While Traveling, Workout session, leisure time
# 45                           Office hours, While Traveling,
# 46                             While Traveling, leisure time
# 47                          While Traveling, Workout session
# 48            While Traveling, Workout session, leisure time
# 49                             While Traveling, leisure time
# 50            While Traveling, Workout session, leisure time
#
#                                music_expl_method  music_recc_rating  \
# spotify_user
# 1                                      Playlists                  3
# 2                                      Playlists                  2
# 3                                      Playlists                  4
# 4                     recommendations, Playlists                  4
# 5                     recommendations, Playlists                  4
# 6                                         Others                  3
# 7                                recommendations                  3
# 8                                recommendations                  5
# 9                               Playlists, Radio                  4
# 10                               recommendations                  4
# 11                                     Playlists                  3
# 12                    recommendations, Playlists                  3
# 13                                     Playlists                  3
# 14                       recommendations, Others                  1
# 15                    recommendations, Playlists                  5
# 16                                        Others                  2
# 17                              Playlists, Radio                  1
# 18                               recommendations                  4
# 19                               recommendations                  3
# 20                               recommendations                  4
# 21                    recommendations, Playlists                  4
# 22                               recommendations                  5
# 23                               recommendations                  4
# 24             recommendations, Playlists, Radio                  1
# 25                        recommendations, Radio                  3
# 26                                        Others                  4
# 27                               recommendations                  4
# 28                               recommendations                  1
# 29                               recommendations                  4
# 30                               recommendations                  3
# 31                                     Playlists                  4
# 32                                     Playlists                  5
# 33                    recommendations, Playlists                  3
# 34                               recommendations                  3
# 35                                     Playlists                  4
# 36                                        Others                  1
# 37             recommendations, Playlists, Radio                  3
# 38                    recommendations, Playlists                  3
# 39                               recommendations                  4
# 40                                     Playlists                  3
# 41            recommendations, Playlists, Others                  4
# 42                                     Playlists                  3
# 43                    recommendations, Playlists                  4
# 44                       recommendations, Others                  5
# 45                    recommendations, Playlists                  5
# 46                                     Playlists                  5
# 47                                        Others                  3
# 48                    recommendations, Playlists                  4
# 49                    recommendations, Playlists                  3
# 50                               recommendations                  4
#
#                  pod_lis_frequency         fav_pod_genre preffered_pod_format  \
# spotify_user
# 1                            Daily                Comedy            Interview
# 2             Several times a week                Comedy            Interview
# 3                      Once a week                Sports            Interview
# 4                            Never                   NaN                  NaN
# 5                           Rarely  Lifestyle and Health        Story telling
# 6                            Never                   NaN                  NaN
# 7                            Never                   NaN                  NaN
# 8             Several times a week  Lifestyle and Health       Conversational
# 9                           Rarely                Comedy        Story telling
# 10                           Never                   NaN                  NaN
# 11            Several times a week  Lifestyle and Health        Story telling
# 12            Several times a week                Comedy            Interview
# 13                          Rarely  Lifestyle and Health        Story telling
# 14                          Rarely                Comedy        Story telling
# 15                          Rarely  Lifestyle and Health          Educational
# 16                           Never                   NaN                  NaN
# 17                           Daily                Comedy          Educational
# 18                           Never                   NaN                  NaN
# 19                           Never                   NaN                  NaN
# 20                           Never                   NaN                  NaN
# 21                           Never                   NaN                  NaN
# 22                           Never                   NaN                  NaN
# 23                     Once a week                Comedy        Story telling
# 24                          Rarely                Comedy            Interview
# 25                          Rarely  Lifestyle and Health       Conversational
# 26                           Never                   NaN                  NaN
# 27            Several times a week  Lifestyle and Health        Story telling
# 28                           Never                   NaN                  NaN
# 29                           Never                   NaN                  NaN
# 30                           Daily                Comedy       Conversational
# 31                          Rarely  Lifestyle and Health       Conversational
# 32                          Rarely                Comedy            Interview
# 33                           Never                   NaN                  NaN
# 34                          Rarely                Comedy       Conversational
# 35                          Rarely                Comedy        Story telling
# 36                           Never                   NaN                  NaN
# 37            Several times a week              Business        Story telling
# 38                          Rarely                Comedy       Conversational
# 39                          Rarely                Comedy        Story telling
# 40                          Rarely                   NaN            Interview
# 41                          Rarely                Comedy                  NaN
# 42                          Rarely                   NaN       Conversational
# 43                     Once a week                Comedy       Conversational
# 44                           Daily    Health and Fitness            Interview
# 45                     Once a week                Comedy        Story telling
# 46                           Never                   NaN                  NaN
# 47                     Once a week  Lifestyle and Health       Conversational
# 48                     Once a week      Food and cooking            Interview
# 49                     Once a week                Comedy                  NaN
# 50                          Rarely                Comedy        Story telling
#
#                  pod_host_preference preffered_pod_duration  \
# spotify_user
# 1                               Both                   Both
# 2                               Both                    NaN
# 3                                NaN                   Both
# 4                                NaN                    NaN
# 5             Well known individuals                   Both
# 6                                NaN                    NaN
# 7                                NaN                    NaN
# 8                               Both                 Longer
# 9             Well known individuals                Shorter
# 10                               NaN                    NaN
# 11                              Both                   Both
# 12                              Both                Shorter
# 13            Well known individuals                Shorter
# 14            Well known individuals                Shorter
# 15            Well known individuals                Shorter
# 16                               NaN                    NaN
# 17            Well known individuals                 Longer
# 18                               NaN                    NaN
# 19                               NaN                    NaN
# 20                               NaN                Shorter
# 21                               NaN                    NaN
# 22                               NaN                    NaN
# 23            Well known individuals                Shorter
# 24                              Both                Shorter
# 25                              Both                   Both
# 26                               NaN                    NaN
# 27                              Both                 Longer
# 28                               NaN                    NaN
# 29                               NaN                    NaN
# 30                              Both                 Longer
# 31            Well known individuals                 Longer
# 32            Well known individuals                   Both
# 33                               NaN                    NaN
# 34                              Both                   Both
# 35            Well known individuals                Shorter
# 36                               NaN                    NaN
# 37                              Both                Shorter
# 38            Well known individuals                Shorter
# 39                              Both                Shorter
# 40                              Both                Shorter
# 41                              Both                Shorter
# 42                              Both                   Both
# 43                              Both                 Longer
# 44            Well known individuals                 Longer
# 45                               NaN                   Both
# 46                               NaN                    NaN
# 47                              Both                   Both
# 48                              Both                Shorter
# 49            Well known individuals                Shorter
# 50                unknown Podcasters                Shorter
#
#              pod_variety_satisfaction
# spotify_user
# 1                                  Ok
# 2                           Satisfied
# 3                           Satisfied
# 4                                  Ok
# 5                                  Ok
# 6                                  Ok
# 7                                  Ok
# 8                           Satisfied
# 9                           Satisfied
# 10                                 Ok
# 11                          Satisfied
# 12                                 Ok
# 13                                 Ok
# 14                                 Ok
# 15                     Very Satisfied
# 16                  Very Dissatisfied
# 17                          Satisfied
# 18                                 Ok
# 19                                 Ok
# 20                                 Ok
# 21                                 Ok
# 22                                 Ok
# 23                          Satisfied
# 24                     Very Satisfied
# 25                                 Ok
# 26                                 Ok
# 27                          Satisfied
# 28                  Very Dissatisfied
# 29                                 Ok
# 30                          Satisfied
# 31                          Satisfied
# 32                          Satisfied
# 33                                 Ok
# 34                                 Ok
# 35                                 Ok
# 36                                 Ok
# 37                                 Ok
# 38                          Satisfied
# 39                          Satisfied
# 40                                 Ok
# 41                                 Ok
# 42                                 Ok
# 43                     Very Satisfied
# 44                     Very Satisfied
# 45                          Satisfied
# 46                                 Ok
# 47                                 Ok
# 48                          Satisfied
# 49                                 Ok
# 50                     Very Satisfied

# %% [markdown]
# ### ETL

# %%
# Remove Pod Columns
columns = [
    'Age',
    'Gender',
    'spotify_usage_period',
    'spotify_listening_device',
    'spotify_subscription_plan',
    'premium_sub_willingness',
    'preffered_premium_plan',
    'preferred_listening_content',
    'fav_music_genre',
    'music_time_slot',
    'music_Influencial_mood',
    'music_lis_frequency',
    'music_expl_method',
    'music_recc_rating',
    'pod_lis_frequency',
]
demo_df = df_spotify[columns].copy().dropna()
demo_df
# Out:
#                 Age  Gender spotify_usage_period  \
# spotify_user
# 1             20-35  Female    More than 2 years
# 2             12-20    Male    More than 2 years
# 3             35-60  Others   6 months to 1 year
# 9             20-35  Female   Less than 6 months
# 17            20-35  Female   Less than 6 months
# ...             ...     ...                  ...
# 516           20-35  Female    More than 2 years
# 517           20-35  Female    More than 2 years
# 518           20-35  Female    More than 2 years
# 519           20-35  Female   6 months to 1 year
# 520           20-35  Female    More than 2 years
#
#                                       spotify_listening_device  \
# spotify_user
# 1                           Smart speakers or voice assistants
# 2                                           Computer or laptop
# 3                           Smart speakers or voice assistants
# 9                                                   Smartphone
# 17                                                  Smartphone
# ...                                                        ...
# 516           Smartphone, Computer or laptop, Wearable devices
# 517                             Smartphone, Computer or laptop
# 518                                                 Smartphone
# 519                                                 Smartphone
# 520                             Smartphone, Computer or laptop
#
#                 spotify_subscription_plan premium_sub_willingness  \
# spotify_user
# 1                     Free (ad-supported)                     Yes
# 2                     Free (ad-supported)                     Yes
# 3                     Free (ad-supported)                     Yes
# 9                     Free (ad-supported)                     Yes
# 17                    Free (ad-supported)                     Yes
# ...                                   ...                     ...
# 516                   Free (ad-supported)                     Yes
# 517                   Free (ad-supported)                     Yes
# 518                   Free (ad-supported)                      No
# 519           Premium (paid subscription)                     Yes
# 520           Premium (paid subscription)                     Yes
#
#                       preffered_premium_plan preferred_listening_content  \
# spotify_user
# 1                   Family Plan-Rs 179/month                     Podcast
# 2             Individual Plan- Rs 119/ month                     Podcast
# 3                   Student Plan-Rs 59/month                     Podcast
# 9             Individual Plan- Rs 119/ month                       Music
# 17            Individual Plan- Rs 119/ month                       Music
# ...                                      ...                         ...
# 516                 Student Plan-Rs 59/month                       Music
# 517                 Student Plan-Rs 59/month                       Music
# 518                 Student Plan-Rs 59/month                       Music
# 519           Individual Plan- Rs 119/ month                       Music
# 520                 Student Plan-Rs 59/month                       Music
#
#              fav_music_genre music_time_slot  \
# spotify_user
# 1                     Melody           Night
# 2                        Rap       Afternoon
# 3                        Pop           Night
# 9                     Melody       Afternoon
# 17                    Melody       Afternoon
# ...                      ...             ...
# 516                      Pop         Morning
# 517                      Pop           Night
# 518                      Pop           Night
# 519                   Melody           Night
# 520                      Pop           Night
#
#                                          music_Influencial_mood  \
# spotify_user
# 1                                         Sadness or melancholy
# 2                                  Social gatherings or parties
# 3                                  Relaxation and stress relief
# 9             Relaxation and stress relief, Uplifting and mo...
# 17                                 Relaxation and stress relief
# ...                                                         ...
# 516           Uplifting and motivational, Sadness or melancholy
# 517           Relaxation and stress relief, Uplifting and mo...
# 518                                Relaxation and stress relief
# 519           Relaxation and stress relief, Uplifting and mo...
# 520           Relaxation and stress relief, Sadness or melan...
#
#                                             music_lis_frequency  \
# spotify_user
# 1                                                  leisure time
# 2                                               Workout session
# 3                                  Study Hours, While Traveling
# 9                                 While Traveling, leisure time
# 17                                While Traveling, leisure time
# ...                                                         ...
# 516                                             While Traveling
# 517              While Traveling, Workout session, leisure time
# 518                                                leisure time
# 519                               Workout session, leisure time
# 520           Office hours,Study Hours, While Traveling, lei...
#
#                     music_expl_method  music_recc_rating     pod_lis_frequency
# spotify_user
# 1                           Playlists                  3                 Daily
# 2                           Playlists                  2  Several times a week
# 3                           Playlists                  4           Once a week
# 9                    Playlists, Radio                  4                Rarely
# 17                   Playlists, Radio                  1                 Daily
# ...                               ...                ...                   ...
# 516                   recommendations                  5                Rarely
# 517                            Others                  2                Rarely
# 518                   recommendations                  3                 Never
# 519           recommendations, Others                  2  Several times a week
# 520                  Playlists, Radio                  3                 Never
#
# [312 rows x 15 columns]

# %% [markdown]
# ## Data Processing

# %%
# Data Preprocessing
# Create a binary column for subscription type (Free = 0, Premium = 1)
df_spotify['is_premium'] = df_spotify['spotify_subscription_plan'].apply(
    lambda x: 0 if x == 'Free' else 1
)

# %%
# Select relevant features for clustering
features = [
    'Age', 'Gender', 'spotify_usage_in_years', 'spotify_listening_device',
    'premium_sub_willingness', 'preffered_premium_plan', 'preferred_content',
    'fav_genre', 'music_time', 'music_Influencial_mood', 'music_lis_frequency',
    'music_expl_method', 'music_recc_rating', 'pod_lis_frequency', 'fav_pod_genre',
    'preffered_pod_format', 'pod_host_preference', 'preffered_pod_duration',
    'pod_variety_satisfaction'
]

# %%
# Create a copy for clustering
df_cluster = df_spotify[features].copy()

# Convert categorical variables to numerical using Label Encoding
label_encoders = {}
for column in df_cluster.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df_cluster[column] = le.fit_transform(df_cluster[column].astype(str))
    label_encoders[column] = le

# %%
# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_cluster)

# Determine optimal number of clusters using Elbow Method and Silhouette Score
inertia = []
silhouette_scores = []
k_values = range(2, 8)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)
    
    if k > 1:  # Silhouette score requires at least 2 clusters
        silhouette_scores.append(silhouette_score(scaled_data, kmeans.labels_))

# %%
# Plot Elbow Curve
elbow_plot = pd.DataFrame({'k': k_values, 'inertia': inertia}).hvplot.line(
    x='k', y='inertia', 
    title='Elbow Method for Optimal k',
    xticks=k_values,
    width=600, height=400
)

# %%
# Plot Silhouette Scores
silhouette_plot = pd.DataFrame({'k': k_values[1:], 'score': silhouette_scores}).hvplot.line(
    x='k', y='score',
    title='Silhouette Scores for Optimal k',
    xticks=k_values[1:],
    width=600, height=400
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Plot Silhouette Scores
# ----> 2 silhouette_plot = pd.DataFrame({'k': k_values[1:], 'score': silhouette_scores}).hvplot.line(
#       3     x='k', y='score',
#       4     title='Silhouette Scores for Optimal k',
#       5     xticks=k_values[1:],
#       6     width=600, height=400
#       7 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
# Display the plots
(elbow_plot + silhouette_plot).cols(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Display the plots
# ----> 2 (elbow_plot + silhouette_plot).cols(1)
#
# NameError: name 'silhouette_plot' is not defined

# %%
# Based on the plots, select the optimal number of clusters
optimal_k = 3  # Adjust this based on your elbow and silhouette plots

# Perform K-means clustering with optimal k
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# Add cluster labels to the original dataframe
df_spotify['cluster'] = clusters

# Reduce dimensions for visualization using PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
df_pca = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
df_pca['cluster'] = clusters
df_pca['subscription'] = df_spotify['spotify_subscription_plan']
df_pca['is_premium'] = df_spotify['is_premium']

# Create cluster visualization
cluster_plot = df_pca.hvplot.scatter(
    x='PC1', y='PC2', 
    by='cluster',
    title='Spotify User Clusters (PCA-reduced)',
    hover_cols=['subscription'],
    width=700, height=500,
    size=100, alpha=0.7
)

# Create visualization colored by subscription type
subscription_plot = df_pca.hvplot.scatter(
    x='PC1', y='PC2', 
    by='subscription',
    title='Spotify Users by Subscription Type (PCA-reduced)',
    width=700, height=500,
    size=100, alpha=0.7
)

# Display the plots
(cluster_plot + subscription_plot).cols(1)

# Analyze cluster characteristics by subscription type
cluster_summary = df_spotify.groupby(['cluster', 'spotify_subscription_plan']).size().unstack()
cluster_percentages = cluster_summary.div(cluster_summary.sum(axis=1), axis=0) * 100

# Plot cluster distribution by subscription type
cluster_dist_plot = cluster_percentages.hvplot.bar(
    title='Cluster Distribution by Subscription Type',
    ylabel='Percentage of Cluster',
    stacked=True,
    width=600, height=400,
    rot=45
)

# Compare premium vs free user characteristics within clusters
def compare_features(df, feature):
    return df.groupby(['cluster', 'spotify_subscription_plan'])[feature].value_counts(normalize=True).unstack().unstack()

# Example comparison for music listening frequency
music_freq_comparison = compare_features(df_spotify, 'music_lis_frequency')
music_freq_plot = music_freq_comparison.hvplot.bar(
    title='Music Listening Frequency by Cluster and Subscription',
    ylabel='Proportion',
    stacked=True,
    width=800, height=500,
    rot=45
)

# Example comparison for preferred content
content_comparison = compare_features(df_spotify, 'preferred_content')
content_plot = content_comparison.hvplot.bar(
    title='Preferred Content by Cluster and Subscription',
    ylabel='Proportion',
    stacked=True,
    width=800, height=500,
    rot=45
)

# Display comparison plots
(cluster_dist_plot + music_freq_plot + content_plot).cols(1)

# Statistical comparison of premium vs free users in each cluster
for cluster in range(optimal_k):
    print(f"\nCluster {cluster} Analysis:")
    cluster_data = df_spotify[df_spotify['cluster'] == cluster]
    
    # Compare premium vs free counts
    premium_count = cluster_data['is_premium'].sum()
    free_count = len(cluster_data) - premium_count
    print(f"Premium users: {premium_count} ({premium_count/len(cluster_data)*100:.1f}%)")
    print(f"Free users: {free_count} ({free_count/len(cluster_data)*100:.1f}%)")
    
    # Compare willingness to pay for premium
    if 'premium_sub_willingness' in cluster_data.columns:
        willingness = cluster_data.groupby('is_premium')['premium_sub_willingness'].value_counts(normalize=True)
        print("\nWillingness to pay for premium:")
        print(willingness)
    
    # Compare top features
    print("\nTop features for this cluster:")
    for feature in ['music_Influencial_mood', 'fav_genre', 'music_time']:
        if feature in cluster_data.columns:
            print(f"\n{feature}:")
            print(cluster_data[feature].value_counts().head(3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Plot Silhouette Scores
# ----> 2 silhouette_plot = pd.DataFrame({'k': k_values[1:], 'score': silhouette_scores}).hvplot.line(
#       3     x='k', y='score',
#       4     title='Silhouette Scores for Optimal k',
#       5     xticks=k_values[1:],
#       6     width=600, height=400
#       7 )
#       9 # Display the plots
#      10 (elbow_plot + silhouette_plot).cols(1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
